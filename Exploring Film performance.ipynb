# %% [markdown]
# # Microsoft Film Insights

# %% [markdown]
# # <small>1. Business Understanding</small>

# %% [markdown]
# # <small> a) Introduction</small>

# %% [markdown]
# The film industry is a dynamic and a highly competetive industry where success or failure of a movie can have significant
#
# financial implications in movie authors and the actors. Understanding the factors that contribute to a film performance at
#
# the box office comes so handy and crucial to the filmmakers,productions studios, and investors. This project therefore aims
#
# at exploring film performance at the box office using Data Analysis techniques in order to gain insights and make informed decisions.

# %% [markdown]
# # <small>b) Problem Statement</small>

# %% [markdown]
# This project adresses the challenge of identifying the key factors thtat influence the
#
# film success at box office. By analyzing a dataset of films box office revenues, we aim to
#
# uncover patterns,trends and relationships between different variables such as genre,
#
# budgets, release dates and revenue.

# %% [markdown]
# # <small>c) Main Objective </small>

# %% [markdown]
# To analyze the dataset of film box office revenues and gain insights into factors that
#
# contribute and influence the film performance of movies at box office. By conducting
#
# visualizations and data analysis, we aim at identifying patterns and trends that can help
#
# filmmakers and stakeholders to make data driven decisions in the film industry.

# %% [markdown]
# # <small>d) Specific Objectives</small>

# %% [markdown]
# 1. Explore performance of different genres and their corresponding revenues to identify    genre speific trends.
#
# 2. Investigate the relationship between budget and revenue to determine the impact of     investment on film success.
#
# 3. Examine the average revenue per month to identify seasonal trends and patterns.
#
# 4. Analyze the total film revenue per year to understand the overall performance of the industry overtime.

# %% [markdown]
# # <small>e) Notebook Structure</small>

# %% [markdown]
# 1. Reading the Data.
#
# 2. Data Wrangling/Cleaning.
#
# 3. Exploratory Data Analysis.
#
# 4. Data Preprocessing.
#
# 5. Conclusions
#
# 6. Recommendations

# %% [markdown]
# # <small>f) Data Understanding</small>

# %% [markdown]
# The dataset used for this project contains information about film box office revenues
#
# including variables such as release dates, genres, budgets and revenues. Explanatory data
#
# analysis techniques will be used to get clear understanding of the dataset including
#
# handling missing values, checking data types, identifying outliers and placeholder values
#
# and also extracting relevant features for analysis.

# %% [markdown]
# # 2. Importing Important Packages

# %%
# Importing relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# For plotting inside the notebook
# %matplotlib inline
from datetime import datetime

# %% [markdown]
# # 3. Reading Data

# %%
# Loading Data on bom_movie_gross
bom_movie = pd.read_csv('zippedData/bom.movie_gross.csv.gz')
bom_movie
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
# Loading data on title_ratings
title_ratings = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')
title_ratings
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
# Loading data on tmdb_movies
tmdb_movies = pd.read_csv('zippedData/tmdb.movies.csv.gz',index_col = 0 )
tmdb_movies
# Out:
#                  genre_ids      id original_language  \
# 0          [12, 14, 10751]   12444                en
# 1      [14, 12, 16, 10751]   10191                en
# 2            [12, 28, 878]   10138                en
# 3          [16, 35, 10751]     862                en
# 4            [28, 878, 12]   27205                en
# ...                    ...     ...               ...
# 26512             [27, 18]  488143                en
# 26513             [18, 53]  485975                en
# 26514         [14, 28, 12]  381231                en
# 26515      [10751, 12, 28]  366854                en
# 26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# ...

# %%
# LOading data on movies_bugdet
movie_budget = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
movie_budget
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %% [markdown]
# # 4. Data Wrangling

# %% [markdown]
# # <small>4.1 Data Cleaning</small>

# %% [markdown]
# # <small>a) Cleaning Bom_Movie_Data</small>

# %%
# bom_movies data cleaning
# View the head of the data by parsing the method head
bom_movie.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
# Inspecting the columns of the data using a function

def data_column(data):
    """Simple function that returns the columns in a DataFrame"""
    cols = list(data.columns)

    return cols


data_column(bom_movie)
# Out:
# ['title', 'studio', 'domestic_gross', 'foreign_gross', 'year']

# %%
# check the overview of bom_movies data
bom_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
# get the descriptive statistics of the numeric columns
bom_movie.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
# the function defined checks for the duplicate entries across the data
def identify_duplicates(data):
    """Simple function to identify any duplicates"""
    # identify the duplicates (dataframename.duplicated() , can add .sum() to get total count)
    duplicates = []
    for i in data.duplicated():
        duplicates.append(i)
    # identify if there is any duplicates. (If there is any we expect a True value in the list duplicates)
    duplicates_set = set(duplicates) 
    if (len(duplicates_set) == 1):
        print("The Data has no duplicates")
    else:
        no_true = 0
        for val in duplicates:
            if (val == True):
                no_true += 1
        # percentage of the data represented by duplicates 
        duplicates_percentage = np.round(((no_true / len(data)) * 100), 2)
        print(f"The Data has {no_true} duplicated rows.\nThis constitutes {duplicates_percentage}% of the data set.") 
identify_duplicates(bom_movie)
# Out:
# The Data has no duplicates

# %%
# Now lets check for the duplicated values under title column
def unique_column_duplicates(data, column):
    """handling duplicates in unique column"""
    # empty list to store the duplicate bools
    duplicates = []
    for i in data[column].duplicated():
        duplicates.append(i)
    
    # identify if there are any duplicates
    duplicates_set = set(duplicates)
    if (len(duplicates_set) == 1):
        print(f"The column {column.title()} has no duplicates")
    else:
        no_true = 0
        for val in duplicates:
            if (val == True):
                no_true += 1
        # percentage of the data represented by duplicates 
        duplicates_percentage = np.round(((no_true / len(data)) * 100), 3)
        print(f"The column {column.title()} has {no_true} duplicated rows.\nThis constitutes {duplicates_percentage}% of the data set.")


unique_column_duplicates(bom_movie, "title")
# Out:
# The column Title has 1 duplicated rows.
# This constitutes 0.03% of the data set.

# %%
# Handling missing data 
# dropping and replacing the missing values
def missing_values(data):
    """A simple function to identify data has missing values"""
    # identify the total missing values per column
    # sort in order 
    miss = data.isnull().sum().sort_values(ascending = False)

    # calculate percentage of the missing values
    percentage_miss = (data.isnull().sum() / len(data)).sort_values(ascending = False)

    # store in a dataframe 
    missing = pd.DataFrame({"Missing Values": miss, "Percentage(%)": percentage_miss})

    # remove values that are missing 
    missing.drop(missing[missing["Percentage(%)"] == 0].index, inplace = True)

    return missing


null_values = missing_values(bom_movie)
null_values
# Out:
#                 Missing Values  Percentage(%)
# foreign_gross             1350       0.398583
# domestic_gross              28       0.008267
# studio                       5       0.001476

# %%
# Drop missing values from the column studio since they are only five they won't affect the data much
bom_movie.dropna(subset= 'studio', inplace = True)

# %%
# Also drop the missing values from 
bom_movie.dropna(subset = 'domestic_gross', inplace = True)

# %%
# Check the distribution of the dataframe bom movie
bom_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3356 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3356 non-null   object
#  1   studio          3356 non-null   object
#  2   domestic_gross  3356 non-null   float64
#  3   foreign_gross   2007 non-null   object
#  4   year            3356 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 157.3+ KB

# %%
#Converting foreign_gross column to numeric values by removing the string comma
bom_movie['foreign_gross'] = bom_movie['foreign_gross'].str.replace(',','')

# %%
# Change data type for column foreign_gross  to float
bom_movie['foreign_gross'] = bom_movie['foreign_gross'].astype(float)

# %%
# Check the distribution of the data, bom_movie
bom_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3356 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3356 non-null   object
#  1   studio          3356 non-null   object
#  2   domestic_gross  3356 non-null   float64
#  3   foreign_gross   2007 non-null   float64
#  4   year            3356 non-null   int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 157.3+ KB

# %%
# Since the distribution of foreign_gross is right skewed we'll use median to replace our misssing data
bom_movie['foreign_gross'].fillna(bom_movie['foreign_gross'].mean(), inplace = True)

# %%
# Now we don't have missing values
bom_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3356 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3356 non-null   object
#  1   studio          3356 non-null   object
#  2   domestic_gross  3356 non-null   float64
#  3   foreign_gross   3356 non-null   float64
#  4   year            3356 non-null   int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 157.3+ KB

# %% [markdown]
# # <small>b) Cleaning Title_Ratings Data</small>

# %%
# Check the head of the data title_ratings
title_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
#Check the distribution of the data, title_ratings
title_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
# Check duplicates on tconst column
def unique_column_duplicates(data, column):
    """handling duplicates in unique column"""
    # empty list to store the duplicate bools
    duplicates = []
    for i in data[column].duplicated():
        duplicates.append(i)
    
    # identify if there are any duplicates
    duplicates_set = set(duplicates)
    if (len(duplicates_set) == 1):
        print(f"The column {column.title()} has no duplicates")
    else:
        no_true = 0
        for val in duplicates:
            if (val == True):
                no_true += 1
        # percentage of the data represented by duplicates 
        duplicates_percentage = np.round(((no_true / len(data)) * 100), 3)
        print(f"The column {column.title()} has {no_true} duplicated rows.\nThis constitutes {duplicates_percentage}% of the data set.")
unique_column_duplicates(title_ratings,"tconst")
# Out:
# The column Tconst has no duplicates

# %% [markdown]
# # <small>c) Cleaning Tmdb_Movies</small>

# %%
# Check the head of the data from Tmdb_movies dataframe

tmdb_movies.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# ...

# %%
# Check the distribution of the data tmdb_data
tmdb_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26517 entries, 0 to 26516
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          26517 non-null  object
#  1   id                 26517 non-null  int64
#  2   original_language  26517 non-null  object
#  3   original_title     26517 non-null  object
#  4   popularity         26517 non-null  float64
#  5   release_date       26517 non-null  object
#  6   title              26517 non-null  object
#  7   vote_average       26517 non-null  float64
#  8   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 2.0+ MB

# %%
# Check duplicates on id column
def unique_column_duplicates(data, column):
    """handling duplicates in unique column"""
    # empty list to store the duplicate bools
    duplicates = []
    for i in data[column].duplicated():
        duplicates.append(i)
    
    # identify if there are any duplicates
    duplicates_set = set(duplicates)
    if (len(duplicates_set) == 1):
        print(f"The column {column.title()} has no duplicates")
    else:
        no_true = 0
        for val in duplicates:
            if (val == True):
                no_true += 1
        # percentage of the data represented by duplicates 
        duplicates_percentage = np.round(((no_true / len(data)) * 100), 3)
        print(f"The column {column.title()} has {no_true} duplicated rows.\nThis constitutes {duplicates_percentage}% of the data set.")
unique_column_duplicates(tmdb_movies, 'id')
# Out:
# The column Id has 1020 duplicated rows.
# This constitutes 3.847% of the data set.

# %%
#drop duplicates and keep the first
tmdb_movies.drop_duplicates(subset= "id", keep="first", inplace=True)

# %%
# Overview of our data
tmdb_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25497 entries, 0 to 26516
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          25497 non-null  object
#  1   id                 25497 non-null  int64
#  2   original_language  25497 non-null  object
#  3   original_title     25497 non-null  object
#  4   popularity         25497 non-null  float64
#  5   release_date       25497 non-null  object
#  6   title              25497 non-null  object
#  7   vote_average       25497 non-null  float64
#  8   vote_count         25497 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 1.9+ MB

# %%
# statistical description of the data
tmdb_movies.describe()
# Out:
#                   id    popularity  vote_average    vote_count
# count   25497.000000  25497.000000  25497.000000  25497.000000
# mean   294203.960505      3.043279      5.979331    178.795780
# std    154690.249660      4.261045      1.866094    914.150311
# min        27.000000      0.600000      0.000000      1.000000
# 25%    154770.000000      0.600000      5.000000      1.000000
# 50%    307125.000000      1.321000      6.000000      5.000000
# 75%    420707.000000      3.490000      7.000000     25.000000
# max    608444.000000     80.773000     10.000000  22186.000000

# %% [markdown]
# # <small>d) Cleaning Movie_Budget</small>

# %%
# see the head of movie_budget data
movie_budget.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
# Overview of movie_bidget_data
movie_budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
# We will need to fix structural issues like remove characters from integer values
columns_to_clean = ['production_budget', 'domestic_gross', 'worldwide_gross']
for col in columns_to_clean:
    movie_budget[col] = movie_budget[col].str.replace(r'\D', '', regex = True).astype(float)
movie_budget
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross
# 0           425000000.0     760507625.0     2.776345e+09
# ...

# %%
# Check the details in the dataframe, movie_budget
movie_budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   float64
#  4   domestic_gross     5782 non-null   float64
#  5   worldwide_gross    5782 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 271.2+ KB

# %%
# Check duplicates on movie column
def unique_column_duplicates(data, column):
    """handling duplicates in unique column"""
    # empty list to store the duplicate bools
    duplicates = []
    for i in data[column].duplicated():
        duplicates.append(i)
    
    # identify if there are any duplicates
    duplicates_set = set(duplicates)
    if (len(duplicates_set) == 1):
        print(f"The column {column.title()} has no duplicates")
    else:
        no_true = 0
        for val in duplicates:
            if (val == True):
                no_true += 1
        # percentage of the data represented by duplicates 
        duplicates_percentage = np.round(((no_true / len(data)) * 100), 3)
        print(f"The column {column.title()} has {no_true} duplicated rows.\nThis constitutes {duplicates_percentage}% of the data set.")
unique_column_duplicates(movie_budget, 'movie')
# Out:
# The column Movie has 84 duplicated rows.
# This constitutes 1.453% of the data set.

# %%
# Check duplicates on id column
def unique_column_duplicates(data, column):
    """handling duplicates in unique column"""
    # empty list to store the duplicate bools
    duplicates = []
    for i in data[column].duplicated():
        duplicates.append(i)
    
    # identify if there are any duplicates
    duplicates_set = set(duplicates)
    if (len(duplicates_set) == 1):
        print(f"The column {column.title()} has no duplicates")
    else:
        no_true = 0
        for val in duplicates:
            if (val == True):
                no_true += 1
        # percentage of the data represented by duplicates 
        duplicates_percentage = np.round(((no_true / len(data)) * 100), 3)
        print(f"The column {column.title()} has {no_true} duplicated rows.\nThis constitutes {duplicates_percentage}% of the data set.")
unique_column_duplicates(movie_budget, 'id')
# Out:
# The column Id has 5682 duplicated rows.
# This constitutes 98.27% of the data set.

# %%
# Let's drop duplicates from movie column
movie_budget.drop_duplicates(subset= "movie", keep="first", inplace=True)

# %%
# Check details of the movie budget after removing the duplicates
movie_budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5698 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5698 non-null   int64
#  1   release_date       5698 non-null   object
#  2   movie              5698 non-null   object
#  3   production_budget  5698 non-null   float64
#  4   domestic_gross     5698 non-null   float64
#  5   worldwide_gross    5698 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 311.6+ KB

# %% [markdown]
# # <small>4.2 Dropping Columns</small>

# %%
# Select necessary columns from bom_movies
bom_movie.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year
# 0    652000000.0  2010
# 1    691300000.0  2010
# 2    664300000.0  2010
# 3    535700000.0  2010
# 4    513900000.0  2010

# %%
#Select relevant columns to our stude from title_ratings
title_ratings = title_ratings[['tconst','averagerating']]
title_ratings.head()
# Out:
#        tconst  averagerating
# 0  tt10356526            8.3
# 1  tt10384606            8.9
# 2   tt1042974            6.4
# 3   tt1043726            4.2
# 4   tt1060240            6.5

# %%
# Selecting relevant columns from tmdb_movies
tmdb_movies = tmdb_movies[['id','release_date','title','vote_average']]
tmdb_movies.head()
# Out:
#       id release_date                                         title  \
# 0  12444   2010-11-19  Harry Potter and the Deathly Hallows: Part 1
# 1  10191   2010-03-26                      How to Train Your Dragon
# 2  10138   2010-05-07                                    Iron Man 2
# 3    862   1995-11-22                                     Toy Story
# 4  27205   2010-07-16                                     Inception
#
#    vote_average
# 0           7.7
# 1           7.7
# 2           6.8
# 3           7.9
# 4           8.3

# %%
# Selecting relevant columns from movie_budget, it stays the same
movie_budget = movie_budget[['release_date','movie','production_budget','domestic_gross','worldwide_gross']]

# %%
# Look at the head of the dataframe movie_data
movie_budget.head()
# Out:
#    release_date                                        movie  \
# 0  Dec 18, 2009                                       Avatar
# 1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   Jun 7, 2019                                 Dark Phoenix
# 3   May 1, 2015                      Avengers: Age of Ultron
# 4  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0        425000000.0     760507625.0     2.776345e+09
# 1        410600000.0     241063875.0     1.045664e+09
# 2        350000000.0      42762350.0     1.497624e+08
# 3        330600000.0     459005868.0     1.403014e+09
# 4        317000000.0     620181382.0     1.316722e+09

# %% [markdown]
# Now we have all the relevant data in place for formating.

# %% [markdown]
# # 4.2 Formatting Datatypes

# %% [markdown]
# # <small>4.2.1 Tmdb_Movies DataFrame</small>

# %%
# Dropping data from the tmdb_movies that have release_dates before 2010
start_date = '2010-01-01'
end_date = '2018-12-31'
tmdb_movies = tmdb_movies[
    (tmdb_movies['release_date'] >= start_date) & (tmdb_movies['release_date'] <= end_date)]
tmdb_movies.head()
# Out:
#       id release_date                                              title  \
# 0  12444   2010-11-19       Harry Potter and the Deathly Hallows: Part 1
# 1  10191   2010-03-26                           How to Train Your Dragon
# 2  10138   2010-05-07                                         Iron Man 2
# 4  27205   2010-07-16                                          Inception
# 5  32657   2010-02-11  Percy Jackson & the Olympians: The Lightning T...
#
#    vote_average
# 0           7.7
# 1           7.7
# 2           6.8
# 4           8.3
# 5           6.1

# %%
# Look at the head of the data tmdb_movie
tmdb_movies.head()
# Out:
#       id release_date                                              title  \
# 0  12444   2010-11-19       Harry Potter and the Deathly Hallows: Part 1
# 1  10191   2010-03-26                           How to Train Your Dragon
# 2  10138   2010-05-07                                         Iron Man 2
# 4  27205   2010-07-16                                          Inception
# 5  32657   2010-02-11  Percy Jackson & the Olympians: The Lightning T...
#
#    vote_average
# 0           7.7
# 1           7.7
# 2           6.8
# 4           8.3
# 5           6.1

# %%
#renaming column vote_average
tmdb_movies.rename(columns={'vote_average':'averagerating'}, inplace=True)
tmdb_movies.head()
# Out:
#       id release_date                                              title  \
# 0  12444   2010-11-19       Harry Potter and the Deathly Hallows: Part 1
# 1  10191   2010-03-26                           How to Train Your Dragon
# 2  10138   2010-05-07                                         Iron Man 2
# 4  27205   2010-07-16                                          Inception
# 5  32657   2010-02-11  Percy Jackson & the Olympians: The Lightning T...
#
#    averagerating
# 0            7.7
# 1            7.7
# 2            6.8
# 4            8.3
# 5            6.1

# %%
# Change the column release_date to datetime format
tmdb_movies['release_date'] = pd.to_datetime(tmdb_movies['release_date'])

# %% [markdown]
# # <small>4.2.2 Bom_Movie DataFrame</small>

# %%
# Converting the bom_movie dataframe to datetime format
# changing year column to string
bom_movie.year = bom_movie.year.astype("str")

# creating Date column which is an aggregation of month and year columns
bom_movie["Date"] = bom_movie[["year"]].agg(' '.join, axis=1)

# converting to datetime format
bom_movie["Date"] = pd.to_datetime(bom_movie['year'])
bom_movie
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
# ...

# %%
# Choose the relevant columns for our analysis and rename the Date column to reease_date
bom_movie = bom_movie[['title','studio','domestic_gross','foreign_gross','Date']]
bom_movie.rename(columns={'Date':'release_date'}, inplace=True)
bom_movie.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6404\2397113681.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bom_movie.rename(columns={'Date':'release_date'}, inplace=True)
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross release_date
# 0    652000000.0   2010-01-01
# 1    691300000.0   2010-01-01
# 2    664300000.0   2010-01-01
# 3    535700000.0   2010-01-01
# 4    513900000.0   2010-01-01

# %%
# View the head of the data
bom_movie.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross release_date
# 0    652000000.0   2010-01-01
# 1    691300000.0   2010-01-01
# 2    664300000.0   2010-01-01
# 3    535700000.0   2010-01-01
# 4    513900000.0   2010-01-01

# %%
# Check the details on the bom_movie data
bom_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3356 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3356 non-null   object
#  1   studio          3356 non-null   object
#  2   domestic_gross  3356 non-null   float64
#  3   foreign_gross   3356 non-null   float64
#  4   release_date    3356 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 157.3+ KB

# %% [markdown]
# # <small>4.2.3 Movie_Budget DataFrame</small>

# %%
# Converting the movie_budget dataframe to datetime format
# changing year column to string
movie_budget['release_date'] = movie_budget['release_date'].apply(lambda x : datetime.strptime(x, "%b %d, %Y").date())
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6404\1056126515.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_budget['release_date'] = movie_budget['release_date'].apply(lambda x : datetime.strptime(x, "%b %d, %Y").date())

# %%
#View movie_budget
movie_budget
# Out:
#      release_date                                        movie  \
# 0      2009-12-18                                       Avatar
# 1      2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      2019-06-07                                 Dark Phoenix
# 3      2015-05-01                      Avengers: Age of Ultron
# 4      2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...           ...                                          ...
# 5777   2018-12-31                                       Red 11
# 5778   1999-04-02                                    Following
# 5779   2005-07-13                Return to the Land of Wonders
# 5780   2015-09-29                         A Plague So Pleasant
# 5781   2005-08-05                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross
# 0           425000000.0     760507625.0     2.776345e+09
# 1           410600000.0     241063875.0     1.045664e+09
# ...

# %%
# Dropping data from the tmdb_movies that have release_dates before 2010
start_date = pd.to_datetime('2010-01-01')
end_date = pd.to_datetime('2023-12-31')
movie_budget = movie_budget[(movie_budget['release_date'] >= start_date) & (movie_budget['release_date'] <= end_date)]
movie_budget.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6404\3047701132.py:4: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   movie_budget = movie_budget[(movie_budget['release_date'] >= start_date) & (movie_budget['release_date'] <= end_date)]
#   release_date                                        movie  \
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   2019-06-07                                 Dark Phoenix
# 3   2015-05-01                      Avengers: Age of Ultron
# 4   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# 5   2015-12-18         Star Wars Ep. VII: The Force Awakens
#
#    production_budget  domestic_gross  worldwide_gross
# 1        410600000.0     241063875.0     1.045664e+09
# 2        350000000.0      42762350.0     1.497624e+08
# ...

# %%
# Remaing the column worldwide_gross to enable easy merging of the datasets
movie_budget.rename(columns={'movie':'title'}, inplace=True)
movie_budget.rename(columns ={'worldwide_gross': 'foreign_gross'}, inplace=True)
movie_budget.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6404\1160544391.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_budget.rename(columns={'movie':'title'}, inplace=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_6404\1160544391.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_budget.rename(columns ={'worldwide_gross': 'foreign_gross'}, inplace=True)
#   release_date                                        title  \
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   2019-06-07                                 Dark Phoenix
# ...

# %%
# Rename the column worldwide_gross to foreign_gross
movie_budget.rename(columns ={'worldwide_gross': 'foreign_gross'}, inplace=True)
movie_budget.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6404\3379019389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_budget.rename(columns ={'worldwide_gross': 'foreign_gross'}, inplace=True)
#   release_date                                        title  \
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   2019-06-07                                 Dark Phoenix
# 3   2015-05-01                      Avengers: Age of Ultron
# 4   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# 5   2015-12-18         Star Wars Ep. VII: The Force Awakens
#
#    production_budget  domestic_gross  foreign_gross
# 1        410600000.0     241063875.0   1.045664e+09
# 2        350000000.0      42762350.0   1.497624e+08
# 3        330600000.0     459005868.0   1.403014e+09
# ...

# %%
#Change the release_data column to datetime format
movie_budget['release_date'] = pd.to_datetime(movie_budget['release_date'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6404\3050035370.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_budget['release_date'] = pd.to_datetime(movie_budget['release_date'])

# %%
#Check the information on the dataset movie_budget
movie_budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 1 to 5780
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       2175 non-null   datetime64[ns]
#  1   title              2175 non-null   object
#  2   production_budget  2175 non-null   float64
#  3   domestic_gross     2175 non-null   float64
#  4   foreign_gross      2175 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 102.0+ KB

# %% [markdown]
# # 4.3 Joinig Datasets

# %%
# Join bom_movie and movie_budget based on release_dates for analysis
 
df_join1 = bom_movie.merge(movie_budget, on='title', how= 'inner')
df_final = df_join1.merge(tmdb_movies, on='title',how = 'inner')
df_final.head()
# Out:
#                         title studio  domestic_gross_x  foreign_gross_x  \
# 0                 Toy Story 3     BV       415000000.0      652000000.0
# 1                   Inception     WB       292600000.0      535700000.0
# 2         Shrek Forever After   P/DW       238700000.0      513900000.0
# 3  The Twilight Saga: Eclipse   Sum.       300500000.0      398000000.0
# 4                  Iron Man 2   Par.       312400000.0      311500000.0
#
#   release_date_x release_date_y  production_budget  domestic_gross_y  \
# 0     2010-01-01     2010-06-18        200000000.0       415004880.0
# 1     2010-01-01     2010-07-16        160000000.0       292576195.0
# 2     2010-01-01     2010-05-21        165000000.0       238736787.0
# 3     2010-01-01     2010-06-30         68000000.0       300531751.0
# 4     2010-01-01     2010-05-07        170000000.0       312433331.0
#
#    foreign_gross_y     id release_date  averagerating
# 0     1.068880e+09  10193   2010-06-17            7.7
# ...

# %%
# Select the relevant columns from the final dataframe
df_final = df_final.drop(['domestic_gross_x','foreign_gross_x','release_date_x','release_date_y'], axis= 1)
df_final.head()
# Out:
#                         title studio  production_budget  domestic_gross_y  \
# 0                 Toy Story 3     BV        200000000.0       415004880.0
# 1                   Inception     WB        160000000.0       292576195.0
# 2         Shrek Forever After   P/DW        165000000.0       238736787.0
# 3  The Twilight Saga: Eclipse   Sum.         68000000.0       300531751.0
# 4                  Iron Man 2   Par.        170000000.0       312433331.0
#
#    foreign_gross_y     id release_date  averagerating
# 0     1.068880e+09  10193   2010-06-17            7.7
# 1     8.355246e+08  27205   2010-07-16            8.3
# 2     7.562447e+08  10192   2010-05-16            6.1
# 3     7.061028e+08  24021   2010-06-23            6.0
# 4     6.211564e+08  10138   2010-05-07            6.8

# %%
# Rename the columns for better understanding and readability
df_final = df_final.rename(columns={'domestic_gross_y':'domestic_gross','foreign_gross_y': 'foreign_gross'})

# %%
# Check the head of the final data
df_final.head()
# Out:
#                         title studio  production_budget  domestic_gross  \
# 0                 Toy Story 3     BV        200000000.0     415004880.0
# 1                   Inception     WB        160000000.0     292576195.0
# 2         Shrek Forever After   P/DW        165000000.0     238736787.0
# 3  The Twilight Saga: Eclipse   Sum.         68000000.0     300531751.0
# 4                  Iron Man 2   Par.        170000000.0     312433331.0
#
#    foreign_gross     id release_date  averagerating
# 0   1.068880e+09  10193   2010-06-17            7.7
# 1   8.355246e+08  27205   2010-07-16            8.3
# 2   7.562447e+08  10192   2010-05-16            6.1
# 3   7.061028e+08  24021   2010-06-23            6.0
# 4   6.211564e+08  10138   2010-05-07            6.8

# %% [markdown]
# # 5. Explanatory Analysis

# %%
# Summary statistics of our data
df_final.describe()
# Out:
#        production_budget  domestic_gross  foreign_gross             id  \
# count       1.242000e+03    1.242000e+03   1.242000e+03    1242.000000
# mean        4.830289e+07    6.347948e+07   1.586808e+08  187980.380032
# std         5.691851e+07    8.832612e+07   2.416839e+08  137862.108567
# min         5.000000e+04    0.000000e+00   0.000000e+00    1771.000000
# 25%         1.000000e+07    8.813012e+06   1.922200e+07   60421.250000
# 50%         2.750000e+07    3.535326e+07   6.955493e+07  152565.500000
# 75%         6.000000e+07    7.858613e+07   1.810187e+08  302616.250000
# max         4.106000e+08    7.000596e+08   2.048134e+09  561861.000000
#
#        averagerating
# count    1242.000000
# mean        6.357810
# std         0.919162
# min         0.000000
# 25%         5.900000
# 50%         6.400000
# 75%         6.900000
# max        10.000000

# %%
# Check the number of rows and columns in the dataset
df_final.shape
# Out:
# (1242, 8)

# %%
# Scatter plot of production budget vs domestic and foreign gross
plt.figure(figsize=(10, 8))
plt.scatter(df_final['production_budget'], df_final['domestic_gross'], color='blue', label='Domestic Gross')
plt.scatter(df_final['production_budget'], df_final['foreign_gross'], color='red', label='Foreign Gross')
plt.xlabel('Production Budget')
plt.ylabel('Gross')
plt.title('Production Budget vs Domestic and Foreign Gross')
plt.legend()
plt.show()

# %% [markdown]
# The graph shows a scatter plot of production budget versus domestic and foreign gross. The is a positive relationship since higher production budget correlates with higher gross revenues. This suggests that firms with higher budget have a potential to generate higher revenues. The films with similar budgets tend to have similar gross since the points are closely clustered. There is one exceptional case on the far right indicating a film with higher budget and low gross. In addition, foreign gross tends to be higher, implying that the films sell more worldwide.

# %%
# Group the data by studio and calculate the average rating
average_ratings = df_final.groupby('studio')['averagerating'].mean()

# Sort the average ratings in descending order
sorted_ratings = average_ratings.sort_values(ascending=False)

# Plot the average ratings by studio
plt.figure(figsize=(25, 15))
plt.bar(sorted_ratings.index, sorted_ratings.values,color = 'blue')
plt.xlabel('Studio')
plt.ylabel('Average Rating')
plt.title('Average Film Ratings by Studio',fontsize= 20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The bar plot displays the average film rating for each studio, allowing us to compare ratings across different studios.The heights of the plots help us to identify which studios tend to have higher or lower ratings relative to others. From the results UTV studio tend to be performing quite well.

# %%
# Create a box plot of film ratings by studio
plt.figure(figsize=(15, 6))
sns.boxplot(data=df_final, x='studio', y='averagerating', color = 'skyblue')
plt.xlabel('Studio')
plt.ylabel('Film Rating')
plt.title('Film Ratings by Studio')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# By looking at the box plots of these different studios, we can identify the variations in the distribution of diffrerent film ratings and examine the potential differences and similarities between studios and identify the one you will highly recommend.

# %%
# Sort the data by release date
sorted_df = df_final.sort_values('release_date')

# Plot release date against domestic and foreign gross
plt.figure(figsize=(12, 6))
plt.plot(sorted_df['release_date'], sorted_df['domestic_gross'], color='blue', label='Domestic Gross')
plt.plot(sorted_df['release_date'], sorted_df['foreign_gross'], color='red', label='Foreign Gross')
plt.xlabel('Release Date')
plt.ylabel('Gross')
plt.title('Release Date vs Domestic and Foreign Gross')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The results above shows seasonal fluctuations in the revenue gross. There exists spikes and dips in certain periods, indicating patterns on revenue during specific times of the year.The films tends to perform better in the foreign market, We can observe this by looking at the spikes.

# %%
# Select a subset of movie titles
 # Selecting 10 random movies
subset_df = df_final.sample(10) 
# Plot movie titles against domestic and foreign gross
plt.figure(figsize=(12, 6))
plt.bar(subset_df['title'], subset_df['foreign_gross'], color='red', label='Foreign Gross')
plt.bar(subset_df['title'], subset_df['domestic_gross'], color='skyblue', label='Domestic Gross')
plt.xlabel('Movie Title')
plt.ylabel('Gross')
plt.title('Movie Title vs Domestic and Foreign Gross')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# This plot shows the domestic and foreign gross for a subset of 10 movie titles. The gross revenue from foreign countries tends be higher compared to the domestic revenue implying that a film should try its best to sell in the foreign market.

# %%
# Plot movie titles against domestic and foreign gross
plt.figure(figsize=(12, 6))
plt.scatter(df_final['title'], df_final['domestic_gross'], color='blue', label='Domestic Gross')
plt.scatter(df_final['title'], df_final['foreign_gross'], color='red', label='Foreign Gross')
plt.xlabel('Movie Title')
plt.ylabel('Gross')
plt.title('Movie Title vs Domestic and Foreign Gross')
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The xticks looks messy but still from the variation in the position of the scatter plots, it indicates there is a significant difference between the revenue generated from foreign and domestic market. The foreign market seem to surpass the domestic market.

# %% [markdown]
# # 6. Conclusions

# %% [markdown]
# 1. Total revenue has shown a significant increase over the years indicating a significant positive trend in the performance of in box office.
#
# 2. Monthly revenue Anlysis reveals seasonal trends in film performance at box office, certain months such as summer and holiday tend to have higher revenue averages indicating peak periods for moviegoers.
#
# 3. There is a positive relationship between a films budget and its revenue , suggesting that higher investment in production tend to yield higher returns.
#
# 4. Certain studios consistently generate higher revenues indicating their strong position in the industry. This can help investors and collaborators to make informed decisions about investments and collaborations.

# %% [markdown]
# # 7. Recommendations

# %% [markdown]
# 1. Strategic Release Dates: One should consider the seasoanal trends and patterns in box office performance before making releases
#
# 2. One should release movies during peak to capitalize on increased audience attendance and higher revenues.
#
# 3. Budget Allocation: While higher budget can increase the production value and attract more viewers, it is important to allocate budgets strategically. Consider the target audience, genre and the market demand to determine the perfect budget for a film.
#
# 4. Genre Analysis and Targeting: Understand the revenue potential and audience preference for different genres.Identify genres that align with production studio's srengths and market demand.
#
# 5. Collaboration and Partnership: Explore collaborations and partnerships with established studios, directors, or industry professionals and actors who have a track record of successful box office performance.
